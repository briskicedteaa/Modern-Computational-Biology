# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Modern-Computational-Biology/blob/main/Multiple_Sequence_Alignment_(MSA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multiple Sequence Alignment with **Clustal** **Omega**

# %% [markdown]
# ### MSA is a conputational process that takes three or more text strings representing DNA, RNA, nucleotides, or proteins, and aligns them vertically so that the maximum number of matching characters line up in columns.
