# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Modern-Computational-Biology/blob/main/Large_Scale_Sequence_Searching_with_MMseqs2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ColabFold v1.6.2: AlphaFold2 using MMseqs2
#
# Firstly, I decided to reuse a protein sequence I've been using all throughout Module 4, which was D2R's sequence (Homo Sapiens). The **objective** of this assignment was to get familiarated with MMseqs2 and compare it to sequence alignment tools like *pairwise sequence alignment,* *MSA*, and *BLAST.*
#
# I utilized the official ColabFold2 AlphaFold notebook to predict the three-dimensional structure of my protein from its sequence. It identified and aligned 17,500 related protein sequences, which AlphaFold used as evolutionary evidence when generating five candidate structural models for my protein.
#
# While I was interested in the results for the most part, I wanted to see what related protein sequences it found and I wanted to search up the first five sequences + analyze similarity.
#
# From the test file found in the notebook containg all related sequences, identifiers for the first 5 related sequences were found from their UniProt ID's:
#
# **D2R Moschus moschiferus**
#
# **D2R Orycteropus afer afer**
#
# **D2R Microcebus murinus**
#
# **D2R Cavia porcellus**
#
# **D2R Mesocricetus auratus**
